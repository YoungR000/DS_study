# %% [markdown]
# # Logistic Regression
#    연속형 data의iput으로 연속형 data를 만들면 Linear Regression
#    연속형 data의iput으로 이산형('0' or '1') data를 만들면 Logistic Regression
#     1. 제품이 불량인지 양품인지
#     2. 고객이 이탈고객 인지 잔류고객 인지
#     3. 카드거래가 정상인지 사기 인지

# %%
from IPython.display import Image

# %%
Image("Logistic Regression/Sig.png")

# %%
Image("Logistic Regression/probabilty.png")

# %%
Image("Logistic Regression/probabilty_1.png")

# %%
Image("Logistic Regression/p_2.png")

# %%
Image("Logistic Regression/p_3.png")

# %%
Image("Logistic Regression/p_4.png")

# %% [markdown]
# ### 승산(odd)에 log 함수를 적용하면 베타1의 의미를 직관적으로 알 수 있음

# %%
Image("Logistic Regression/p_5.png")

# %%
Image("Logistic Regression/p_6.png")

# %%
Image("Logistic Regression/p_7.png")

# %% [markdown]
# ##하이퍼 파라미터 : penalty , C
#   C(cost function) : 값이 크면 높은 코스트 -> 훈련을 더 복잡하게 -> 약한 규제?
#                      값이 작으면 낮은 코스트 -> 훈련을 덜 복잡하게 -> 강한 규제?

# %%
Image("Logistic Regression/p_8.png")

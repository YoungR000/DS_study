# %% [markdown]
# # kNN (K-Nearest Neighbor ) 알고리즘
#     상세 원리 설명 및 하이퍼파라미터 상세 분석 및 노하우 정리

# %%
from IPython.display import Image

# %%
Image("kNN/image_dog_cat.png")

# %%
Image("kNN/ml.jpg")

# %% [markdown]
# ## "유유상종"  "같은 날개를 가진 새들끼리 함께 모인다" 거리기반 분류분석 모델
#   K-NN 알고리즘은 어떤 새로운 데이터로부터 거리가 가까운 K개의 다른 데이터의 레이블(속성)을 참고하여 K개의 데이터
#   중 가장 빈도 수가 높게 나온 데이터의 레이블로 분류하는 알고리즘

# %%
Image("kNN/K1.png")

# %% [markdown]
# ## Hyperparameter
#    하이퍼 파라미터란, 일반적으로 머신러닝에서 어떠한 임의의 모델을 학습시킬때, 사람이 직접 튜닝 (설정) 해주어야하는 변수
#     1. Distance (거리)  - 가중치(weighting) 개념으로 활용
#     2. K=? 1~100  K값은 짝수로 두면 안됨. 0/1 빈도수가 같아져서 결정을 못함.

# %%
Image("kNN/titanic_kNN.png")

# %% [markdown]
# ## K값에 따른 성능 (오버피팅, 언더피팅)
#     K값이 너무 큰 경우 언더피팅, 너무 작으면 오버피팅

# %%
Image("kNN/K_2.png")
